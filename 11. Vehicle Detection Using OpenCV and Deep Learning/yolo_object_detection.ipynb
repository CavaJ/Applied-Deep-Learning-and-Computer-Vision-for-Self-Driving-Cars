# %% [markdown]
# # YOLO v3 Object Detection
#
# Since we can't reasonably train the YOLOv3 network ourself, we will use a pre-trained version.
#
# CODE SOURCE: https://github.com/xiaochus/YOLOv3
#
# REFERENCE (for original YOLOv3):
#
#         @article{YOLOv3,
#               title={YOLOv3: An Incremental Improvement},
#               author={J Redmon, A Farhadi },
#               year={2018}
# --------
# ----------
#
# -------
# -------

# %%
import os
import time
import cv2
import numpy as np
from model.yolo_model import YOLO
# Out:
# Using TensorFlow backend.

# %%
def process_image(img):
    """Resize, reduce and expand image.

    # Argument:
        img: original image.

    # Returns
        image_org: ndarray(416, 416, 3), processed image.
    """
    image_org = cv2.resize(img, (416, 416),
                       interpolation=cv2.INTER_CUBIC)
    image_org = np.array(image_org, dtype='float32')
    image_org /= 255.
    image_org = np.expand_dims(image_org, axis=0)

    return image_org

# %%
def get_classes(file):
    """Get classes name.

    # Argument:
        file: classes name for database.

    # Returns
        name_of_class: List, classes name.

    """
    with open(file) as f:
        name_of_class = f.readlines()
    name_of_class = [c.strip() for c in name_of_class]

    return name_of_class

# %%
def box_draw(image, boxes, scores, classes, all_classes):
    """Draw the boxes on the image.

    # Argument:
        image: original image.
        boxes: ndarray, boxes of objects.
        classes: ndarray, classes of objects.
        scores: ndarray, scores of objects.
        all_classes: all classes name.
    """
    for box, score, cl in zip(boxes, scores, classes):
        x, y, w, h = box

        top = max(0, np.floor(x + 0.5).astype(int))
        left = max(0, np.floor(y + 0.5).astype(int))
        right = min(image.shape[1], np.floor(x + w + 0.5).astype(int))
        bottom = min(image.shape[0], np.floor(y + h + 0.5).astype(int))

        cv2.rectangle(image, (top, left), (right, bottom), (255, 0, 0), 2)
        cv2.putText(image, '{0} {1:.2f}'.format(all_classes[cl], score),
                    (top, left - 6),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    0.6, (0, 0, 255), 1,
                    cv2.LINE_AA)

        print('class: {0}, score: {1:.2f}'.format(all_classes[cl], score))
        print('box coordinate x,y,w,h: {0}'.format(box))

    print()

# %%
def detect_image(image, yolo, all_classes):
    """Use yolo v3 to detect images.

    # Argument:
        image: original image.
        yolo: YOLO, yolo model.
        all_classes: all classes name.

    # Returns:
        image: processed image.
    """
    pimage = process_image(image)

    start = time.time()
    image_boxes, image_classes, image_scores = yolo.predict(pimage, image.shape)
    end = time.time()

    print('time: {0:.2f}s'.format(end - start))

    if image_boxes is not None:
        box_draw(image, image_boxes, image_scores, image_classes, all_classes)

    return image

# %%
def detect_video(video, yolo, all_classes):
    """Use yolo v3 to detect video.

    # Argument:
        video: video file.
        yolo: YOLO, yolo model.
        all_classes: all classes name.
    """
    video_path = os.path.join("videos", "test", video)
    camera = cv2.VideoCapture(video_path)
    cv2.namedWindow("detection", cv2.WINDOW_AUTOSIZE)

    # Prepare for saving the detected video
    sz = (int(camera.get(cv2.CAP_PROP_FRAME_WIDTH)),
        int(camera.get(cv2.CAP_PROP_FRAME_HEIGHT)))
    fourcc = cv2.VideoWriter_fourcc(*'mpeg')

    
    vout = cv2.VideoWriter()
    vout.open(os.path.join("videos", "res", video), fourcc, 20, sz, True)

    while True:
        res, frame = camera.read()

        if not res:
            break

        image = detect_image(frame, yolo, all_classes)
        cv2.imshow("detection", image)

        # Save the video frame by frame
        vout.write(image)

        if cv2.waitKey(110) & 0xff == 27:
                break

    vout.release()
    camera.release()

# %%
yolo = YOLO(0.6, 0.5)
file = 'data/coco_classes.txt'
all_classes = get_classes(file)
# Out:
# C:\Users\CavaJ\anaconda3\envs\tf_env\lib\site-packages\keras\engine\saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %% [markdown]
# ### Detecting Images

# %%
import numpy
numpy.version.version
# Out:
# '1.19.2'

# %%
f = "bike.jpg"
path = 'images/test/bike.jpg'
image = cv2.imread(path)

# %%
cv2.imshow("Image", image)
cv2.waitKey(0)      # Wait until a key is pressed
cv2.destroyAllWindows()

# %%
image = detect_image(image, yolo, all_classes)
cv2.imwrite('images/res/' + f, image)
# Out:
# time: 6.26s
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 55.18435925  39.11145359 113.44946826 221.09623522]
# class: motorbike, score: 1.00
# box coordinate x,y,w,h: [ 13.94717002 120.46722442 267.23246479 232.99697042]
# True

# %%
cv2.imshow("Image", image)
cv2.waitKey(0)      # Wait until a key is pressed
cv2.destroyAllWindows()

# %% [markdown]
# # Detecting on Video

# %%
# # detect videos one at a time in videos/test folder    
video = 'library1.mp4'
detect_video(video, yolo, all_classes)
# Out:
# time: 0.25s
# class: person, score: 1.00
# box coordinate x,y,w,h: [422.23278522 476.16264343 173.45146179 374.28127289]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [369.07299042 635.68248749 295.8633399  255.98869324]
#
# time: 0.15s
# class: person, score: 1.00
# box coordinate x,y,w,h: [401.1204958  476.81552887 175.63248396 369.44404602]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [333.17788839 629.88777161 318.90310764 263.77017975]
#
# time: 0.15s
# class: person, score: 1.00
# box coordinate x,y,w,h: [387.98531055 483.27121735 185.45428276 369.34684753]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [319.77164984 671.82174683 346.40806675 246.46860123]
#
# time: 0.15s
# class: person, score: 1.00
# box coordinate x,y,w,h: [387.6414299  482.35279083 184.81746197 358.74885559]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [320.5562067  649.58030701 330.62785864 247.75081635]
#
# time: 0.14s
# class: person, score: 1.00
# box coordinate x,y,w,h: [380.89543819 481.66236877 191.67003393 367.69485474]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [309.51983929 675.86013794 346.84764862 242.9650116 ]
#
# time: 0.06s
# class: person, score: 1.00
# box coordinate x,y,w,h: [379.00518894 473.30814362 190.52839994 383.9226532 ]
# class: bicycle, score: 1.00
# box coordinate x,y,w,h: [307.20421314 666.54602051 354.51241493 260.42491913]
#
# time: 0.08s
# class: person, score: 1.00
# box coordinate x,y,w,h: [374.89552975 472.15553284 198.6477685  394.3088913 ]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [296.85616493 668.61869812 377.72704124 262.31363297]
#
# time: 0.06s
# class: person, score: 1.00
# box coordinate x,y,w,h: [380.87822914 464.28730011 196.19011402 420.35270691]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [296.01815701 663.31504822 386.01176262 279.13911819]
#
# time: 0.06s
# class: person, score: 1.00
# box coordinate x,y,w,h: [386.71089649 455.44750214 193.64602804 441.90834045]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [292.92617083 661.69242859 392.66059399 280.9176445 ]
#
# time: 0.06s
# class: person, score: 1.00
# box coordinate x,y,w,h: [390.13360977 472.00378418 180.80796719 413.70258331]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [291.11604452 663.41110229 397.87806988 279.20291901]
#
# time: 0.06s
# class: person, score: 1.00
# box coordinate x,y,w,h: [391.79760933 471.66358948 180.27573109 423.15692902]
# class: person, score: 0.67
# box coordinate x,y,w,h: [359.95343685 596.27761841 292.8371644  307.76716232]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [286.42805815 658.4009552  414.30288792 288.26433182]
#
# time: 0.06s
# class: person, score: 0.98
# box coordinate x,y,w,h: [414.61625576 473.8199234  193.32266092 411.58409119]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [293.87580156 657.04948425 400.5818224  296.33563995]
#
# time: 0.05s
# class: person, score: 0.99
# box coordinate x,y,w,h: [413.53989601 467.84885406 199.61862087 420.47660828]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [268.34846735 683.67599487 475.67122936 270.28608322]
#
# time: 0.06s
# class: person, score: 0.99
# box coordinate x,y,w,h: [419.27321434 467.10407257 191.67061329 425.72059631]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [266.40084028 676.74514771 483.48843098 284.4908905 ]
#
# time: 0.07s
# class: person, score: 0.97
# box coordinate x,y,w,h: [423.15216064 477.66220093 186.36022568 403.96701813]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [281.49455309 677.88719177 461.41320705 290.42375565]
#
# time: 0.07s
# class: person, score: 0.96
# box coordinate x,y,w,h: [413.45689774 441.77082062 211.76374912 480.16654968]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [270.20397663 677.81303406 484.08516884 291.00261688]
#
# time: 0.07s
# class: person, score: 0.94
# box coordinate x,y,w,h: [369.02415276 509.54864502 292.15577602 430.77651978]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [278.70514154 640.93276978 461.92450047 349.37339783]
#
# time: 0.08s
# class: person, score: 0.91
# box coordinate x,y,w,h: [363.99936676 509.34577942 296.09834433 431.01047516]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [278.91967535 643.06793213 459.12324429 350.75462341]
#
# time: 0.09s
# class: person, score: 0.95
# box coordinate x,y,w,h: [339.11681414 506.22795105 299.88654613 449.60964203]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [276.06844425 640.82878113 459.25409317 349.59518433]
#
# time: 0.08s
# class: person, score: 0.96
# box coordinate x,y,w,h: [334.85937595 511.61682129 293.35545301 445.66146851]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [283.75067711 625.12435913 410.28468132 361.19644165]
#
# time: 0.09s
# class: person, score: 0.99
# box coordinate x,y,w,h: [372.05393314 434.14115906 215.63306093 494.8960495 ]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [263.96271229 623.66027832 432.02156067 366.96655273]
#
# time: 0.09s
# class: person, score: 0.99
# box coordinate x,y,w,h: [359.58318472 447.17113495 230.56590557 464.16099548]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [215.9884429  676.62757874 493.81120205 288.11475754]
#
# time: 0.15s
# class: person, score: 0.98
# box coordinate x,y,w,h: [343.24361801 463.98990631 244.61686134 437.64732361]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [216.19626045 645.14907837 479.75990295 347.37575531]
#
# time: 0.15s
# class: person, score: 0.98
# box coordinate x,y,w,h: [336.30776882 454.09416199 237.27140665 453.46660614]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [213.24737549 633.46328735 438.34324837 351.09035492]
#
# time: 0.14s
# class: person, score: 0.99
# box coordinate x,y,w,h: [319.26037788 469.87789154 208.44804525 413.61793518]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [172.47792721 676.75537109 489.86526489 294.67903137]
#
# time: 0.06s
# class: person, score: 1.00
# box coordinate x,y,w,h: [297.03698874 472.00714111 222.24393368 403.80146027]
# class: bicycle, score: 0.98
# box coordinate x,y,w,h: [141.15805149 689.48783875 517.75148392 276.97216034]
#
# time: 0.06s
# class: person, score: 1.00
# box coordinate x,y,w,h: [268.65687847 464.16404724 211.99628592 408.17546844]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [163.00925732 632.69241333 423.84970665 355.11165619]
#
# time: 0.06s
# class: person, score: 1.00
# box coordinate x,y,w,h: [259.06401157 471.10733032 219.22404528 400.99460602]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [114.42189932 685.34332275 467.3876667  279.5368576 ]
#
# time: 0.06s
# class: person, score: 1.00
# box coordinate x,y,w,h: [247.68236876 470.34858704 209.02360439 404.48932648]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [115.89140654 676.19064331 421.16977215 284.81599808]
#
# time: 0.06s
# class: person, score: 0.99
# box coordinate x,y,w,h: [235.32212734 474.73323822 213.30434561 404.54658508]
# class: bicycle, score: 1.00
# box coordinate x,y,w,h: [101.460886   677.98141479 433.43193054 280.87806702]
#
# time: 0.06s
# class: person, score: 1.00
# box coordinate x,y,w,h: [214.17833805 478.4803772  208.10459375 389.44549561]
# class: bicycle, score: 1.00
# box coordinate x,y,w,h: [ 74.08439398 682.60894775 439.0031147  276.29756927]
#
# time: 0.06s
# class: person, score: 1.00
# box coordinate x,y,w,h: [202.81220913 479.21424866 198.25582266 372.29324341]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [ 51.49120331 685.56343079 462.48527527 265.31423569]
#
# time: 0.08s
# class: person, score: 1.00
# box coordinate x,y,w,h: [190.47001362 487.22763062 201.84170008 346.54079437]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [ 55.57030678 678.44924927 415.8520031  272.59431839]
#
# time: 0.08s
# class: person, score: 0.99
# box coordinate x,y,w,h: [163.62309694 485.75077057 197.71532536 353.93959045]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [ 56.55517101 682.19047546 383.34929466 262.22982407]
#
# time: 0.08s
# class: person, score: 1.00
# box coordinate x,y,w,h: [149.51094389 491.99539185 207.26420403 349.21325684]
# class: bicycle, score: 1.00
# box coordinate x,y,w,h: [ 28.12160969 685.26603699 401.33807659 255.34440994]
#
# time: 0.08s
# class: person, score: 1.00
# box coordinate x,y,w,h: [141.72902942 493.5042572  204.16822672 341.58321381]
# class: bicycle, score: 1.00
# box coordinate x,y,w,h: [ 28.7540102  681.71913147 372.47308731 261.94673538]
#
# time: 0.08s
# class: person, score: 0.99
# box coordinate x,y,w,h: [115.59732914 504.60842133 189.30554867 320.02220154]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [ 19.47191477 674.86999512 355.25630951 257.07557678]
#
# time: 0.13s
# class: person, score: 1.00
# box coordinate x,y,w,h: [102.07807302 496.13483429 196.69973373 345.5304718 ]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [ 11.51030302 673.45573425 337.63290882 257.35534668]
#
# time: 0.15s
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 89.69540834 493.44753265 199.58669186 345.911026  ]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [  3.77273083 681.42951965 317.8818512  247.25727081]
#
# time: 0.15s
# class: person, score: 0.99
# box coordinate x,y,w,h: [ 63.77948642 504.38159943 181.92934513 316.12710953]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [-14.15318012 681.24801636 331.01688623 234.24037933]
#
# time: 0.14s
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 54.52458858 501.09577179 177.74516344 321.39945984]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [-15.28883815 683.48709106 303.98839474 225.73600769]
#
# time: 0.06s
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 37.83244014 491.90101624 190.91835022 341.36203766]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [-14.5228529  685.77545166 279.73860741 219.52083588]
#
# time: 0.08s
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 23.04474592 493.22971344 196.47288322 346.43165588]
# class: bicycle, score: 0.95
# box coordinate x,y,w,h: [-16.61300182 684.46578979 268.29226971 220.70625305]
#
# time: 0.05s
# class: person, score: 1.00
# box coordinate x,y,w,h: [  6.081056   482.01099396 176.99460626 350.30982971]
# class: bicycle, score: 0.97
# box coordinate x,y,w,h: [-12.98852205 644.36264038 232.80089378 242.37693787]
#
# time: 0.07s
# class: person, score: 1.00
# box coordinate x,y,w,h: [  4.80804741 484.00306702 166.60897493 341.84452057]
# class: bicycle, score: 0.96
# box coordinate x,y,w,h: [ -9.87318993 649.52079773 209.35647726 229.90558624]
#
# time: 0.06s
# class: person, score: 0.99
# box coordinate x,y,w,h: [  2.7889502  492.70027161 160.64712167 312.94109344]
# class: bicycle, score: 0.81
# box coordinate x,y,w,h: [ -4.19680953 642.97019958 182.30438232 224.78565216]
#
# time: 0.05s
# class: person, score: 0.99
# box coordinate x,y,w,h: [3.96285653e-01 4.75018692e+02 1.52915322e+02 3.44839897e+02]
# class: bicycle, score: 0.69
# box coordinate x,y,w,h: [ -0.87207735 637.13577271 157.64712453 215.08304596]
#
# time: 0.07s
# class: person, score: 0.89
# box coordinate x,y,w,h: [ 10.72451234 496.19560242 106.38001442 323.20957184]
# class: bicycle, score: 0.91
# box coordinate x,y,w,h: [  9.37290967 609.14306641 120.99124074 288.64559174]
#
# time: 0.06s
# class: person, score: 0.77
# box coordinate x,y,w,h: [ -4.19835716 437.16480255  88.62594724 379.5552063 ]
# class: bicycle, score: 0.85
# box coordinate x,y,w,h: [  7.34632373 580.10452271 107.87748098 287.5369072 ]
#
# time: 0.08s
# class: person, score: 0.73
# box coordinate x,y,w,h: [ -6.1909005  427.04399109  84.37852442 399.15016174]
# class: bicycle, score: 0.85
# box coordinate x,y,w,h: [ -9.6969822  577.17639923 101.89239979 287.247715  ]
#
# time: 0.07s
# class: bicycle, score: 0.83
# box coordinate x,y,w,h: [-12.48559177 574.01191711  95.54107904 279.8078537 ]
#
# time: 0.08s
# class: bicycle, score: 0.67
# box coordinate x,y,w,h: [-10.83675474 582.99919128  89.97731924 269.96458054]
#
# time: 0.08s
# time: 0.08s
# time: 0.08s
# time: 0.09s
# class: motorbike, score: 0.66
# box coordinate x,y,w,h: [593.47981453 737.98408508 126.61370873 170.76797485]
#
# time: 0.09s
# class: motorbike, score: 0.73
# box coordinate x,y,w,h: [573.68652821 738.16963196 147.48511434 169.17417526]
#
# time: 0.08s
# class: motorbike, score: 0.81
# box coordinate x,y,w,h: [533.20478439 724.53201294 187.84425974 185.82107544]
#
# time: 0.11s
# class: motorbike, score: 0.85
# box coordinate x,y,w,h: [503.90201569 706.31095886 193.10063839 210.86824417]
#
# time: 0.15s
# class: motorbike, score: 0.81
# box coordinate x,y,w,h: [481.12246513 701.65527344 223.32939148 209.86085892]
#
# time: 0.14s
# time: 0.15s
# time: 0.06s
# time: 0.06s
# time: 0.06s
# time: 0.07s
# time: 0.06s
# class: motorbike, score: 0.68
# box coordinate x,y,w,h: [327.46257305 660.6804657  271.59355402 219.24591064]
#
# time: 0.06s
# class: motorbike, score: 0.67
# box coordinate x,y,w,h: [292.11346149 695.04386902 282.43995667 203.15937042]
#
# time: 0.08s
# class: motorbike, score: 0.78
# box coordinate x,y,w,h: [278.60570669 653.62716675 290.48508167 232.98185349]

# %%
# # detect videos one at a time in videos/test folder    
video = 'video.mp4'
detect_video(video, yolo, all_classes)
